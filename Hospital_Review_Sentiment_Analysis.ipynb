# %%
#Utils
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
from tqdm import tqdm

#NLP
import nltk
from nltk import sent_tokenize, word_tokenize, RegexpParser
from nltk.sentiment.util import mark_negation
from nltk.corpus import stopwords, wordnet
from nltk.stem.wordnet import WordNetLemmatizer 
from nltk.tag import pos_tag

#Machine Learning
from sklearn.model_selection import GridSearchCV, StratifiedKFold, train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report

#WordCloud
from wordcloud import WordCloud

#Radar Chart
import plotly.express as px
from plotly.offline import download_plotlyjs, init_notebook_mode,  plot

# %%
#Download resource
nltk.download("stopwords")
nltk.download("punkt")
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('words')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
"""
        Preprocessing text for TfidfVectorizer
          - remove non-character
          - tokenization
          - stopword removal
          - lemmatization
        Parameters
        ----------
        reviews : list
             reviews of customer in hospital
        Return
        ----------
        cleaned_reviews : list
             Preprocessed Reviews  
"""
def preprocess_review(reviews): 
    cleaned_reviews = []
    for review in reviews:
        review = re.sub("[^a-zA-Z]", " ", review)
        words = word_tokenize(review) 
        tokenized_words = [word.lower() for word in words if word not in stopwords.words("english")]
        lemmatized_word = lemmatize_word(tokenized_words)
        cleaned_reviews.append(lemmatized_word)
    return cleaned_reviews

# %%
def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return 'a'

# %%
def lemmatize_word(tokenized_words): 
    lemmatizer = WordNetLemmatizer() 
    lemmatized_words = []
    for word, tag in pos_tag(tokenized_words):
        pos = get_wordnet_pos(tag)
        lemmatized_words.append(lemmatizer.lemmatize(word, pos))
    lemmatized_words = ' '.join([str(word) for word in lemmatized_words]) 
    return lemmatized_words

# %%
def extract_sentences(df):
  sentences = []
  scores = [] 
  cids = [] 
  for cid in df["cid"]:
    en = df.loc[cid, "review"]
    score = df.loc[cid, "rating"]
    s = sent_tokenize(en)
    sentences = sentences + s
    scores = scores + [score]*len(s)
    cids = cids + [cid] * len(s) 
  return pd.DataFrame({"reviews": sentences, "ratings": scores, "cids": cids})

# %%
def train_multinomial_nb(X_train, X_test, y_train, y_test):
     
    tfidf_vectorizer = TfidfVectorizer()
    multinomial_nb_clf = MultinomialNB()
    multinomial_naive_bayes_pipeline = Pipeline([
            ('tfidf', tfidf_vectorizer),
            ('classifier', multinomial_nb_clf)
    ])
    multinomial_naive_bayes_params = {}
    grid = GridSearchCV(multinomial_naive_bayes_pipeline, param_grid = multinomial_naive_bayes_params, cv = 10, scoring = 'roc_auc')
    grid.fit(X_train, y_train)
     
    print("Best Score : %.2f" %  grid.best_score_)
    print("Best Params : ")
    print(grid.best_params_)
    
    y_pred = grid.predict(X_test)
    print("Accuracy : %.2f" % accuracy_score(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    return grid.best_estimator_

# %%
def train_random_forest(X_train, X_test, y_train, y_test):
    
    tfidf_vectorizer = TfidfVectorizer()
    rf_clf =  RandomForestClassifier(random_state=2020, class_weight="balanced")
    rf_pipeline = Pipeline([
            ('tfidf', tfidf_vectorizer),
            ('classifier', rf_clf)
    ])
    rf_params = {
        "classifier__n_estimators": range(50, 200, 50),
        "classifier__max_depth": range(2, 10, 2), 
        "classifier__min_samples_leaf": range(1, 4)
    }
    grid = GridSearchCV(rf_pipeline, param_grid=rf_params, cv=10, scoring='roc_auc')
    grid.fit(X_train, y_train) 
    
    print("Best Score : %.2f" %  grid.best_score_)
    print("Best Params : ")
    print(grid.best_params_)
    
    y_pred = grid.predict(X_test)
    print("Accuracy : %.2f" % accuracy_score(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    return grid.best_estimator_

# %%
def train_svm(X_train, X_test, y_train, y_test):
     
    tfidf_vectorizer = TfidfVectorizer()
    svm_clf =  SVC(random_state=2020, class_weight="balanced", probability=True)
    svm_pipeline = Pipeline([
            ('tfidf', tfidf_vectorizer),
            ('classifier', svm_clf)
    ])
    svm_params = {
        "classifier__C": [ 0.1, 0.5, 1, 5, 10 ],
        "classifier__gamma": np.arange(0.1,1,0.1)
    }
    grid = GridSearchCV(svm_pipeline, param_grid=svm_params, cv=10, scoring='roc_auc')
    grid.fit(X_train, y_train) 
    
    print("Best Score : %.2f" %  grid.best_score_)
    print("Best Params : ")
    print(grid.best_params_)
    
    y_pred = grid.predict(X_test)
    print("Accuracy : %.2f" % accuracy_score(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    return grid.best_estimator_

# %%
def predict_sentiment(estimator, df):
  sentiments = []
  for sentence in df["reviews"]: 
    sentiment = estimator.predict([sentence])
    if sentiment == 1:
      sentiment = "positive"
    else:
      sentiment = "negative"
    sentiments.append( sentiment ) 
  return sentiments

# %%
def plural2singular(word):
  if word == "doctors":
    return "doctor"
  elif word == "nurses":
    return "nurse"
  elif word == "clinics":
    return "clinic"
  elif word == "hospitals":
    return "hospital"
  elif word == "services":
    return "service"
  elif word == "staffs":
    return "staff"
  elif word == "treatments":
    return "treatment"
  elif word == "students":
    return "student"
  else:
    return word

# %%
def create_parsed_trees(df):
  grammar = """NP: {<NN|NNS>+}
                 {<NN|NNS>+<CC><NN|NNS>+}"""
  chunker = RegexpParser(grammar)
  parse_trees = []
  for sentence in df['reviews']:
      parse_trees.append(chunker.parse(pos_tag(word_tokenize(sentence))))
  return parse_trees

# %%
def extract_noun_phrases(parsed_trees):
    nps = []
    for parsed_tree in parsed_trees:
      np = []
      for subtree in parsed_tree.subtrees():
          if subtree.label() == 'NP':
              t = subtree
              t = " ".join(word for word, tag in t.leaves())
              np.append(t)
      nps.append(np)
    return nps

# %%
def vizwordcloud(df, colormap = 'viridis'):
    tuples = [tuple(x) for x in df.values]
    wordcloud = WordCloud(width=1000,height=800,colormap=colormap,max_words=100).generate_from_frequencies(dict(tuples))
    plt.figure(figsize=(20,10))
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis("off")
    plt.show()

# %%
def get_data_for_wordcloud(df, sentiment):
  sentiment_only = df[df["sentiments"] == sentiment].reset_index(drop=True)
  words = sum(sentiment_only["NP"].tolist(), [])
  words = [word.lower() for word in words]
  words = [plural2singular(word) for word in words]
  hist = pd.DataFrame({"words": words})
  short_sentiment = sentiment[0:3]
  hist = hist.groupby("words").size().reset_index(name="#"+short_sentiment)
  return hist

# %% [markdown]
# # Model Training

# %%
train_test_data = pd.read_csv("train_test_data.csv", index_col=False, header = 0, names = ['review_th', 'rating', 'review'])
train_test_data = train_test_data.reset_index()
train_test_data = train_test_data.rename(columns={"index": "cid"})
train_test_data = extract_sentences(train_test_data) 
train_test_data["cleaned_reviews"] = preprocess_review(train_test_data["reviews"])

# %%
X = train_test_data["cleaned_reviews"]
y = train_test_data["ratings"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 2020)

# %% [markdown]
# **Multinomial Naive Bayes**

# %%
multinomial_nb_classifier = train_multinomial_nb(X_train, X_test, y_train, y_test)
# Out:
# Best Score : 0.79
# Best Params :
# {}
# Accuracy : 0.76
#               precision    recall  f1-score   support
#
#            0       0.77      0.75      0.76       409
#            1       0.74      0.77      0.75       381
#
#    micro avg       0.76      0.76      0.76       790
#    macro avg       0.76      0.76      0.76       790
# weighted avg       0.76      0.76      0.76       790

# %% [markdown]
# **Random Forest**

# %%
random_forest_classifier = train_random_forest(X_train, X_test, y_train, y_test)
# Out:
# Best Score : 0.77
# Best Params :
# {'classifier__max_depth': 8, 'classifier__min_samples_leaf': 1, 'classifier__n_estimators': 100}
# Accuracy : 0.69
#               precision    recall  f1-score   support
#
#            0       0.66      0.83      0.74       409
#            1       0.75      0.54      0.62       381
#
#    micro avg       0.69      0.69      0.69       790
#    macro avg       0.70      0.68      0.68       790
# weighted avg       0.70      0.69      0.68       790

# %% [markdown]
# **Support Vector Machine**

# %%
svm_classifier = train_svm(X_train, X_test, y_train, y_test)
# Out:
# Best Score : 0.78
# Best Params :
# {'classifier__C': 1, 'classifier__gamma': 0.2}
# Accuracy : 0.73
#               precision    recall  f1-score   support
#
#            0       0.70      0.85      0.77       409
#            1       0.79      0.61      0.69       381
#
#    micro avg       0.73      0.73      0.73       790
#    macro avg       0.74      0.73      0.73       790
# weighted avg       0.74      0.73      0.73       790

# %% [markdown]
# # Bumrungrad Hospital

# %%
bumrungrad = pd.read_csv("bumrungrad-translated.csv", index_col=False, header = 0, names = ['review_th', 'rating', 'review'])
bumrungrad = bumrungrad.reset_index()
bumrungrad = bumrungrad.rename(columns={"index": "cid"})
bumrungrad = extract_sentences(bumrungrad) 
bumrungrad["cleaned_reviews"] = preprocess_review(bumrungrad["reviews"])

# %%
bumrungrad["sentiments"] = predict_sentiment(multinomial_nb_classifier, bumrungrad)

# %%
bumrungrad["NP"] = extract_noun_phrases(create_parsed_trees(bumrungrad))

# %%
bumrungrad
# Out:
#                                                reviews  ratings  cids  \
# 0                     Hospitals are very well behaved.        1     0
# 1                  There's a very good doctor patient.        1     0
# 2    Nurses do not bother me face cafeteria clean, ...        1     0
# 3    The Banco vaccine and the detection of allergi...        1     0
# 4    This treatment is here The X-ray machines thro...        1     0
# 5                   Nursing bright toys those children        1     0
# 6      I gained knowledge from this article very much.        1     1
# 7                 And can be applied in everyday life.        1     1
# 8                                 It may fit all ages.        1     1
# 9       In the article, readers can understand easily.        1     1
# 10   This article from the medical hospital in simp...        1     1
# 11   It is not complicated I will help guide and in...        1     1
# 12                 And it's available here many times.        1     1
# 13                     Put their trust in the service.        1     1
# 14     I gained knowledge from this article very much.        1     2
# 15                And can be applied in everyday life.        1     2
# 16                                It may fit all ages.        1     2
# 17      In the article, readers can understand easily.        1     2
# 18   This article from the medical hospital in simp...        1     2
# 19   It is not complicated I will help guide and in...        1     2
# 20                 And it's available here many times.        1     2
# 21                     Put their trust in the service.        1     2
# 22   Bumrungrad Hospital Providing excellent care t...        1     3
# 23   Fully equipped modern, affordable health care ...        1     3
# 24   Let's take a look at who it is, try to see it ...        1     3
# 25                  To reassure people Excellent fever        1     3
# 26     I gained knowledge from this article very much.        1     4
# 27                And can be applied in everyday life.        1     4
# 28                                It may fit all ages.        1     4
# 29      In the article, readers can understand easily.        1     4
# ..                                                 ...      ...   ...
# 591  The pressures of life, others Rํg and felt tha...        1   229
# 592                        I saw smiles And greetings.        1   229
# 593        Ever come across an event that is not okay.        1   229
# 594                  It has sent a message to the web.        1   229
# 595      Get a quick fix and instant changes to panic.        1   229
# 596  The drug awareness Waiting time for medical st...        1   229
# 597  He then walked over to ask every time they saw...        1   229
# 598                                         Maybe not.        1   229
# 599  Maybe Pharmacy conspired to observe our behavi...        1   229
# 600  Sometimes we are calling for intolerance and p...        1   229
# 601  I have used Social Security But he took care o...        1   229
# 602  I want to visit all the places I have to move ...        1   229
# 603  Here we will focus on the treatment of foreign...        1   230
# 604  But it also suggests that doctors still have s...        1   230
# 605  (But not as much as compared to hospital where...        1   230
# 606  The doctor sent us to handle multiple test and...        1   230
# 607               This says So why do so many options.        1   230
# 608  It's not about me We very sick He will return ...        1   230
# 609                     So consult your doctor second.        1   230
# 610  Who do you say the name of the doctor you love...        1   230
# 611                  Advise and diagnose very clearly.        1   230
# 612                    If the picture still okay here.        1   230
# 613                  I was very much impressed by you.        1   230
# 614  At first thought as Dubailand, I choose to dis...        0   231
# 615  I do not care now here in Thailand as well as ...        0   231
# 616             I thought to myself I did not know it.        0   231
# 617   The nurse noted that this was not very friendly.        0   231
# 618           I took my wife to the doctor on my time.        0   231
# 619  Wait very long at first, but before the foreig...        0   231
# 620                             I really appreciate it        0   231
#
#                                        cleaned_reviews sentiments  \
# 0                                 hospital well behave   positive
# 1                            there good doctor patient   positive
# 2    nurse bother face cafeteria clean good front i...   positive
# 3            the banco vaccine detection allergy child   positive
# 4    this treatment the x ray machine modern expert...   positive
# 5                             nursing bright toy child   negative
# 6                        i gain knowledge article much   positive
# 7                              and apply everyday life   positive
# 8                                       it may fit age   positive
# 9                  in article reader understand easily   positive
# 10           this article medical hospital simple term   positive
# 11         it complicate i help guide inform knowledge   positive
# 12                             and available many time   positive
# 13                                   put trust service   positive
# 14                       i gain knowledge article much   positive
# 15                             and apply everyday life   positive
# 16                                      it may fit age   positive
# 17                 in article reader understand easily   positive
# 18           this article medical hospital simple term   positive
# 19         it complicate i help guide inform knowledge   positive
# 20                             and available many time   positive
# 21                                   put trust service   positive
# 22   bumrungrad hospital provide excellent care wel...   positive
# 23   fully equip modern affordable health care good...   positive
# 24   let take look try see provide friendly doctor ...   positive
# 25                  to reassure people excellent fever   positive
# 26                       i gain knowledge article much   positive
# 27                             and apply everyday life   positive
# 28                                      it may fit age   positive
# 29                 in article reader understand easily   positive
# ..                                                 ...        ...
# 591  the pressure life others r g felt something wa...   negative
# 592                           i saw smile and greeting   positive
# 593                        ever come across event okay   negative
# 594                                it send message web   positive
# 595                 get quick fix instant change panic   positive
# 596  the drug awareness wait time medical staff eit...   positive
# 597            he walk ask every time saw us wait long   positive
# 598                                              maybe   positive
# 599  maybe pharmacy conspire observe behavior repea...   positive
# 600  sometimes call intolerance perhaps even uncons...   positive
# 601        i use social security but take care us even   positive
# 602                   i want visit place i move really   positive
# 603                     here focus treatment foreigner   positive
# 604                      but also suggest doctor still   negative
# 605  but much compare hospital else ever go find do...   positive
# 606  the doctor send us handle multiple test come b...   positive
# 607                            this say so many option   negative
# 608           it we sick he return doctor obstetrician   positive
# 609                           so consult doctor second   positive
# 610                      who say name doctor love much   positive
# 611                            advise diagnose clearly   positive
# 612                              if picture still okay   positive
# 613                                   i much impressed   positive
# 614         at first thought dubailand i choose discus   negative
# 615                        i care thailand well nation   positive
# 616                                     i think i know   negative
# 617                            the nurse note friendly   positive
# 618                            i take wife doctor time   negative
# 619  wait long first foreigner arrive unexpectedly ...   positive
# 620                                i really appreciate   positive
#
#                                                     NP
# 0                                          [Hospitals]
# 1                                     [doctor patient]
# 2                     [Nurses, clean, front, diameter]
# 3            [vaccine, detection, allergies, children]
# 4            [treatment, machines, Experts, boy, food]
# 5                                     [toys, children]
# 6                                 [knowledge, article]
# 7                                               [life]
# 8                                               [ages]
# 9                                   [article, readers]
# 10                          [article, hospital, terms]
# 11                                         [knowledge]
# 12                                             [times]
# 13                                    [trust, service]
# 14                                [knowledge, article]
# 15                                              [life]
# 16                                              [ages]
# 17                                  [article, readers]
# 18                          [article, hospital, terms]
# 19                                         [knowledge]
# 20                                             [times]
# 21                                    [trust, service]
# 22                                              [care]
# 23       [health care, way, services, people, service]
# 24                                      [look, doctor]
# 25                                     [people, fever]
# 26                                [knowledge, article]
# 27                                              [life]
# 28                                              [ages]
# 29                                  [article, readers]
# ..                                                 ...
# 591  [pressures, life, others, something, patient, ...
# 592                                [smiles, greetings]
# 593                                            [event]
# 594                                     [message, web]
# 595                                     [fix, changes]
# 596                      [drug awareness, time, staff]
# 597                                             [time]
# 598                                                 []
# 599                                [behavior, warning]
# 600                                      [intolerance]
# 601                                             [care]
# 602                                           [places]
# 603                            [treatment, foreigners]
# 604                                          [doctors]
# 605                             [doctor, menstruation]
# 606                      [doctor, test, round, doctor]
# 607                                          [options]
# 608                                           [doctor]
# 609                                    [doctor second]
# 610                                     [name, doctor]
# 611                                                 []
# 612                                          [picture]
# 613                                                 []
# 614                                          [thought]
# 615                                          [nations]
# 616                                                 []
# 617                                            [nurse]
# 618                               [wife, doctor, time]
# 619                                       [foreigners]
# 620                                                 []
#
# [621 rows x 6 columns]

# %%
bumrungrad_positive = get_data_for_wordcloud(bumrungrad, "positive")
vizwordcloud(bumrungrad_positive)

# %%
bumrungrad_negative = get_data_for_wordcloud(bumrungrad, "negative")
vizwordcloud(bumrungrad_negative, "inferno")

# %% [markdown]
# # Lerdsin Hospital

# %%
lerdsin = pd.read_csv("lerdsin-translated.csv", index_col=False, header = 0, names = ['review_th', 'rating', 'review'])
lerdsin = lerdsin.reset_index()
lerdsin = lerdsin.rename(columns={"index": "cid"})
lerdsin = extract_sentences(lerdsin) 
lerdsin["cleaned_reviews"] = preprocess_review(lerdsin["reviews"])

# %%
lerdsin["sentiments"] = predict_sentiment(multinomial_nb_classifier, lerdsin)

# %%
lerdsin["NP"] = extract_noun_phrases(create_parsed_trees(lerdsin))

# %%
lerdsin
# Out:
#                                                 reviews  ratings  cids  \
# 0     I can't remember which year it was at the end ...        1     0
# 1                     At that time we were hemorrhoids.        1     0
# 2     Do not dare to see a doctor because of fear of...        1     0
# 3     Looking at our trembling fears when knowing th...        1     0
# 4                      He said it was a lethal disease.        1     0
# 5     Is a disease that many people have If the lump...        1     0
# 6                                      We are external.        1     0
# 7     I read that I was going to have anesthesia, an...        1     0
# 8     Knowledge of when cutting a knife May not hurt...        1     0
# 9     The doctor would probably catch even though we...        1     0
# 10       Get a 30 baht privilege to treat all diseases.        1     0
# 11             I think it was definitely an anesthetic.        1     0
# 12    Because not paying cash Stroke in the bed, the...        1     0
# 13    But when entering the operating room, move the...        1     0
# 14                       Not really more than a minute.        1     0
# 15       Realizing again at the bed in the shared room.        1     0
# 16     Well..there is a lot of relief that is finished.        1     0
# 17    And we weren't aware that it wasn't just anest...        1     0
# 18    It's very happy to not be aware when undergoin...        1     0
# 19    But when I read on the web, who says that the ...        1     0
# 20                                             Walking?        1     0
# 21                                               Strut.        1     0
# 22    But it really hurts like a pain when walking u...        1     0
# 23                         The sleep is not full sleep.        1     0
# 24    Just know that when we sleep, our body can get...        1     0
# 25    Only the bottom of the curving cord was awake,...        1     0
# 26    Take recovery time after surgery at the bed in...        1     0
# 27    It's really hard to walk, sit, sit, sit comfor...        1     0
# 28                               The shit doesn't hurt.        1     0
# 29                           In our case, it's 1 month.        1     0
# ...                                                 ...      ...   ...
# 1433                               Updated this thread.        0   385
# 1434  I want to step out of the hospital since birth...        0   386
# 1435  Nursing a damn gossip patients Services practi...        0   386
# 1436  There is no reason to pay for the service is bad.        0   386
# 1437  My complaint The service does not systematical...        0   387
# 1438  As a result, the department does not check to ...        0   387
# 1439  No computer system to ensure that the patient ...        0   387
# 1440  Call the call was ignored until the patient is...        0   387
# 1441                   Not by the queue before - after.        0   387
# 1442       Patients come from 8:00 until 11:00 o'clock.        0   387
# 1443  Has not yet been cultivated speak dispensing u...        0   387
# 1444  Service damn much like a dog does not speak Ri...        0   388
# 1445       Bone regeneration at the feet and toes here.        1   389
# 1446  Receive treatment from a medical doctor and ha...        1   390
# 1447  Wait from 10 am until 2 pm to get drugs than a...        1   391
# 1448  But doctors say no He spoke very straight No o...        1   391
# 1449  Followed all the symptoms the patient is disch...        1   392
# 1450  I asked the doctor replied not show signs of f...        1   392
# 1451               If anything, it's driving me to ask.        1   392
# 1452  Beaming nurse was not reprimanded or berated p...        1   392
# 1453  You have the knowledge, expertise treated on t...        1   393
# 1454  Have a pretty good mind Always encourage patie...        1   393
# 1455  The queue is long, because the government hosp...        1   393
# 1456                       But the quality is very good        1   393
# 1457  Good service, attentive caregivers provide goo...        1   394
# 1458  Orthopedic oncology professor Dr. Piya honor S...        1   395
# 1459  Care and counseling is very good, including a ...        1   395
# 1460  Doctors caring for patients with very good siz...        1   396
# 1461                                  Excellent Service        1   397
# 1462            Possible treatment by the unit on site.        1   398
#
#                                         cleaned_reviews sentiments  \
# 0                              i remember year end year   positive
# 1                                    at time hemorrhoid   negative
# 2     do dare see doctor fear treatment hurt and emb...   positive
# 3     look tremble fear know need commit read inform...   positive
# 4                                 he say lethal disease   positive
# 5     be disease many people if lump inside rubber b...   positive
# 6                                           we external   positive
# 7     i read i go anesthesia anesthetize even though...   positive
# 8     knowledge cut knife may hurt hurt little but f...   positive
# 9     the doctor would probably catch even though so...   positive
# 10                     get baht privilege treat disease   positive
# 11                        i think definitely anesthetic   positive
# 12    because pay cash stroke bed wheelchair push op...   positive
# 13    but enter operating room move bed bend face do...   negative
# 14                                    not really minute   negative
# 15                               realize bed share room   positive
# 16                               well lot relief finish   negative
# 17            and aware anesthetic we inhale anesthesia   positive
# 18                  it happy aware undergo surgery scar   positive
# 19           but i read web say dissection complete day   negative
# 20                                                 walk   positive
# 21                                                strut   positive
# 22              but really hurt like pain walking stair   positive
# 23                                 the sleep full sleep   positive
# 24                        just know sleep body get butt   negative
# 25          only bottom curve cord awake sore like pain   positive
# 26    take recovery time surgery bed hospital day ni...   positive
# 27          it really hard walk sit sit sit comfortably   positive
# 28                                        the shit hurt   positive
# 29                                        in case month   positive
# ...                                                 ...        ...
# 1433                                      update thread   negative
# 1434    i want step hospital since birth come wait room   negative
# 1435  nursing damn gossip patient service practice u...   negative
# 1436                       there reason pay service bad   negative
# 1437  my complaint the service systematically send p...   negative
# 1438  as result department check listen result next day   negative
# 1439           no computer system ensure patient locate   negative
# 1440  call call ignored patient already unbearable p...   negative
# 1441                                          not queue   positive
# 1442                                 patient come clock   negative
# 1443  have yet cultivate speak dispense unit separat...   negative
# 1444  service damn much like dog speak riksdag since...   negative
# 1445                         bone regeneration foot toe   positive
# 1446  receive treatment medical doctor good track he...   positive
# 1447  wait pm get drug home go doctor symptom like a...   negative
# 1448  but doctor say he speak straight no one tell i...   negative
# 1449                   follow symptom patient discharge   positive
# 1450  i ask doctor reply show sign frustration frien...   positive
# 1451                              if anything drive ask   negative
# 1452               beam nurse reprimand berated patient   negative
# 1453                 you knowledge expertise treat spot   positive
# 1454  have pretty good mind always encourage patient...   positive
# 1455                 the queue long government hospital   negative
# 1456                                   but quality good   positive
# 1457  good service attentive caregiver provide good ...   positive
# 1458  orthopedic oncology professor dr piya honor se...   positive
# 1459  care counsel good include pep talk fear diseas...   positive
# 1460  doctor care patient good size patient doctor s...   positive
# 1461                                  excellent service   positive
# 1462                       possible treatment unit site   positive
#
#                                                      NP
# 0                                     [year, end, year]
# 1                                   [time, hemorrhoids]
# 2     [doctor, fear, treatment, butt, others, person...
# 3                  [fears, information, web, treatment]
# 4                                             [disease]
# 5     [disease, people, lump, inside, rubber band, f...
# 6                                                    []
# 7               [anesthesia, anesthetize, doctor, butt]
# 8            [knife, feeling, treatment, feeling, fear]
# 9                               [doctor, security card]
# 10                           [baht privilege, diseases]
# 11                                                   []
# 12              [cash, bed, wheelchair, operating room]
# 13    [operating room, bed, face, doctor, mouth, mov...
# 14                                             [minute]
# 15                                          [bed, room]
# 16                                        [lot, relief]
# 17                                         [anesthesia]
# 18                                 [undergoing surgery]
# 19                              [web, dissection, days]
# 20                                                   []
# 21                                                   []
# 22                                       [pain, stairs]
# 23                                       [sleep, sleep]
# 24                                         [body, butt]
# 25                         [bottom, curving cord, pain]
# 26    [recovery time, surgery, bed, hospital, days, ...
# 27                                      [sit, sit, sit]
# 28                                               [shit]
# 29                                        [case, month]
# ...                                                 ...
# 1433                                           [thread]
# 1434                            [hospital, birth, room]
# 1435  [damn gossip patients, practice, treatment, ho...
# 1436                                  [reason, service]
# 1437    [complaint, service, patient file cases, shots]
# 1438                 [result, department, results, day]
# 1439                         [computer system, patient]
# 1440                      [call, patient, patient file]
# 1441                                            [queue]
# 1442                                [Patients, o'clock]
# 1443               [unit, security queues, waste, time]
# 1444  [dog, answer, foot pine, hospital, nothing, heel]
# 1445                         [regeneration, feet, toes]
# 1446              [treatment, doctor, track healthcare]
# 1447  [Wait, pm, drugs, home, doctor, symptoms, reflux]
# 1448                              [doctors, one, water]
# 1449                                [symptoms, patient]
# 1450             [doctor, signs, frustration, patients]
# 1451                                         [anything]
# 1452                                  [nurse, patients]
# 1453                                  [knowledge, spot]
# 1454  [mind, encourage patients, nurses, eloquence, ...
# 1455                      [queue, government hospitals]
# 1456                                          [quality]
# 1457                      [service, caregivers, advice]
# 1458                   [oncology professor, department]
# 1459          [counseling, pep talk, disease, patients]
# 1460  [Doctors, patients, size, doctor, face, person...
# 1461                                                 []
# 1462                            [treatment, unit, site]
#
# [1463 rows x 6 columns]

# %%
lerdsin_positive = get_data_for_wordcloud(lerdsin, "positive")
vizwordcloud(lerdsin_positive)

# %%
lerdsin_negative = get_data_for_wordcloud(lerdsin, "negative")
vizwordcloud(lerdsin_negative, "inferno")

# %% [markdown]
# # Rajavithi Hospital

# %%
rajavithi = pd.read_csv("rajavithi-translated.csv", index_col=False, header = 0, names = ['review_th', 'rating', 'review'])
rajavithi = rajavithi.reset_index()
rajavithi = rajavithi.rename(columns={"index": "cid"})
rajavithi = extract_sentences(rajavithi) 
rajavithi["cleaned_reviews"] = preprocess_review(rajavithi["reviews"])

# %%
rajavithi["sentiments"] = predict_sentiment(multinomial_nb_classifier, rajavithi)

# %%
rajavithi["NP"] = extract_noun_phrases(create_parsed_trees(rajavithi))

# %%
rajavithi
# Out:
#                                                reviews  ratings  cids  \
# 0         Hospital beautiful atmosphere with cool air.        1     0
# 1    To ease Hospital staffs all very nice to me si...        1     0
# 2    It is recommended that people wait to fill out...        1     0
# 3                         What to do in the next step.        1     0
# 4    Which floor to go to the doctor As I reached t...        1     0
# 5    Nurses and doctors generous The treatment is e...        1     0
# 6              Center Specialty Hospital is very good.        1     1
# 7    You are all very kind and very good mentor is ...        1     1
# 8            You have to go a bit to get to the queue.        1     1
# 9    Of medicine at the hospital, it is very inexpe...        1     1
# 10   The expected cost of the treatment is affordable.        1     1
# 11   It also provides tools to inspect the facilities.        1     1
# 12                      The doctor has a lot of rooms.        1     1
# 13   You are very kind At the first examination str...        1     1
# 14   But the doctor was invited to make stress disa...        1     1
# 15   Make love to this very He had little time for ...        1     1
# 16   Doctors and nurses serving good Health success...        1     2
# 17   System checks that pay patients receive an app...        1     2
# 18   Monitoring tools are modern, clean and the ser...        1     2
# 19             The building is new Lift a little less.        1     2
# 20           Bathrooms smell, but is reasonably clean.        1     2
# 21   Staff are constantly cleaning\r\nA cafeteria a...        1     2
# 22   Enough to meet demand\r\nGetting comfortable P...        1     2
# 23   Services provided by nurses and doctors very g...        1     3
# 24   The hospital has to buy shops and markets of o...        1     3
# 25   The food was delicious But he had to wait a lo...        1     3
# 26           I'm waiting on some very hot with no fan.        1     3
# 27   Each one will be prepared to be ready to leave...        1     3
# 28   Hospital Rajvithi To maintain and service very...        1     4
# 29   Since your doctor your medical staff officers ...        1     4
# ..                                                 ...      ...   ...
# 519          But nurses are fed milk for our children.        1   135
# 520             At first, I did not feel I had to ask.        1   135
# 521  He explained that nurses Glass bottles are not...        1   135
# 522  But he said the glass entry way is to eat like...        1   135
# 523                          I have to quibble lap up.        1   135
# 524  Practice using the tongue to stimulate the bre...        1   135
# 525               Our milk comes to a little bit more.        1   135
# 526           The nurse said that if milk really tiny.        1   135
# 527  It's better feeder accessories It's not good t...        1   135
# 528      Do not risk the yellow balls Nha Be District.        1   135
# 529                             Follow may be heavier.        1   135
# 530      It incrementally better (It's less stressful.        1   135
# 531  Believes that medical advice), we asked all th...        1   135
# 532  But he said that he did not have any milk too ...        1   135
# 533  The mother tries to pump .... impression that ...        1   135
# 534  And answer questions After leaving hospital wa...        1   135
# 535       Hospital and medical services are very good.        1   136
# 536                           The service is very bad.        0   137
# 537  Officials also talked like I was forced to ans...        0   137
# 538  Several department officials, but it is the sa...        0   137
# 539  Excellent Service The doctor kindly answered a...        1   138
# 540  SLE is a disease itself has more than 20 years...        1   139
# 541  Department of Internal Medicine, Rheumatology ...        1   139
# 542  The doctor was very kind, lovely, calm poise a...        1   139
# 543             He arranged to meet You will not mind.        1   139
# 544  (Perhaps the realization itself) consult on al...        1   139
# 545  Even non-disease treatment The examination of ...        1   139
# 546           You never leave the patient gets to eat.        1   139
# 547  Check out each day to patients than the patien...        1   139
# 548  Dr. Wally treatment Patients closely I say, co...        1   140
#
#                                        cleaned_reviews sentiments  \
# 0               hospital beautiful atmosphere cool air   positive
# 1                    to ease hospital staff nice since   positive
# 2     it recommend people wait fill new patient i know   negative
# 3                                       what next step   negative
# 4    which floor go doctor as i reach front check wait   negative
# 5    nurse doctor generous the treatment expensive ...   positive
# 6                       center specialty hospital good   positive
# 7    you kind good mentor great keep warm nurse lovely   positive
# 8                                 you go bit get queue   negative
# 9    of medicine hospital inexpensive easily access...   positive
# 10              the expected cost treatment affordable   positive
# 11               it also provide tool inspect facility   positive
# 12                                 the doctor lot room   positive
# 13                you kind at first examination stress   positive
# 14             but doctor invite make stress disappear   positive
# 15     make love he little time speculation first step   positive
# 16   doctor nurse serve good health successfully tr...   positive
# 17   system check pay patient receive appointment c...   negative
# 18      monitoring tool modern clean service expensive   positive
# 19                   the building new lift little less   negative
# 20                     bathroom smell reasonably clean   positive
# 21     staff constantly clean a cafeteria variety shop   positive
# 22   enough meet demand get comfortable park enough...   negative
# 23                   service provide nurse doctor good   positive
# 24                the hospital buy shop market patient   positive
# 25   the food delicious but wait long time go early...   negative
# 26                                      i wait hot fan   negative
# 27   each one prepare ready leave home reserve seat...   positive
# 28          hospital rajvithi to maintain service good   positive
# 29        since doctor medical staff officer stretcher   positive
# ..                                                 ...        ...
# 519                          but nurse feed milk child   positive
# 520                              at first i feel i ask   negative
# 521  he explain nurse glass bottle allow enter cork...   negative
# 522               but say glass entry way eat like cat   negative
# 523                                      i quibble lap   positive
# 524               practice use tongue stimulate breast   positive
# 525                           our milk come little bit   positive
# 526                     the nurse say milk really tiny   positive
# 527     it good feeder accessory it good hold together   positive
# 528                do risk yellow ball nha be district   negative
# 529                                 follow may heavier   positive
# 530            it incrementally well it less stressful   positive
# 531                    believe medical advice ask milk   positive
# 532                     but say milk good i breastfeed   positive
# 533  the mother try pump impression code conduct staff   positive
# 534  and answer question after leave hospital feed ...   positive
# 535                      hospital medical service good   positive
# 536                                    the service bad   negative
# 537    official also talk like i force answer question   negative
# 538  several department official almost every depar...   positive
# 539  excellent service the doctor kindly answer que...   positive
# 540          sle disease year treat high finish doctor   positive
# 541  department internal medicine rheumatology almo...   positive
# 542  the doctor kind lovely calm poise treatment pa...   positive
# 543                           he arrange meet you mind   negative
# 544                 perhaps realization consult matter   positive
# 545  even non disease treatment the examination pat...   positive
# 546                    you never leave patient get eat   positive
# 547  check day patient patient pm it nearly pm you ...   negative
# 548  dr wally treatment patient closely i say compa...   positive
#
#                                                     NP
# 0                                     [beautiful, air]
# 1                                             [staffs]
# 2                                    [people, patient]
# 3                                               [step]
# 4                        [floor, doctor, front, check]
# 5                         [Nurses, doctors, treatment]
# 6                                                   []
# 7                                [kind, mentor, nurse]
# 8                                         [bit, queue]
# 9                                 [medicine, hospital]
# 10                                   [cost, treatment]
# 11                                 [tools, facilities]
# 12                                [doctor, lot, rooms]
# 13                          [kind, examination stress]
# 14                                 [doctor, disappear]
# 15                     [love, time, speculation, step]
# 16                        [Doctors, nurses, treatment]
# 17   [System checks, patients, appointment card, tidy]
# 18                         [Monitoring tools, service]
# 19                                          [building]
# 20                                             [smell]
# 21                  [Staff, cafeteria, variety, shops]
# 22                                            [demand]
# 23                         [Services, nurses, doctors]
# 24                [hospital, shops, markets, patients]
# 25                  [food, time, trouble, parking lot]
# 26                                               [fan]
# 27                          [home, seat, wait, doctor]
# 28                                                  []
# 29                            [doctor, staff officers]
# ..                                                 ...
# 519                           [nurses, milk, children]
# 520                                                 []
# 521                      [nurses, bottles, cork stuck]
# 522                             [glass entry way, cat]
# 523                                              [lap]
# 524                                   [tongue, breast]
# 525                                        [milk, bit]
# 526                                      [nurse, milk]
# 527                               [feeder accessories]
# 528                                            [balls]
# 529                                                 []
# 530                                                 []
# 531                           [Believes, advice, milk]
# 532                                             [milk]
# 533         [mother, impression, code, conduct, staff]
# 534  [questions, hospital, milk, %, % milk powder, ...
# 535                               [Hospital, services]
# 536                                          [service]
# 537                             [Officials, questions]
# 538                 [department officials, department]
# 539                       [doctor, questions, concern]
# 540                           [disease, years, doctor]
# 541                                                 []
# 542  [doctor, kind, poise, treatment, patients, ref...
# 543                                                 []
# 544                    [realization, consult, matters]
# 545     [treatment, examination, patient, lunch break]
# 546                                          [patient]
# 547           [day, patients, patients, pm, pm, lunch]
# 548  [treatment, drugs advantages, disadvantages, d...
#
# [549 rows x 6 columns]

# %%
rajavithi_positive = get_data_for_wordcloud(rajavithi, "positive")
vizwordcloud(rajavithi_positive)

# %%
rajavithi_negative = get_data_for_wordcloud(rajavithi, "negative")
vizwordcloud(rajavithi_negative, "inferno")

# %% [markdown]
# # Radar Chart

# %%
def groups(word):
    if word in ("doctor", "nurse", "student", "security guard"):
        return "staff"
    elif word in ("hospital", "clinic", "equipment", "place","building","room"):
        return "infrastructure"
    elif word in ("care", "treatment", "advice", "surgery", "disease", "medical care", "service", "responsibility","manner","talking" ):
        return "service"
    elif word in ("queue", "appointment","process", "management"):
        return "process"
    elif word in ("price", "claim"):
        return "finance"
    else:
        return "others"

# %%
def  catagory_pos(pos_df): 
    pos_df["category"] = pos_df["words"].apply(lambda x: groups(x))
    hos_poscount = pos_df.groupby("category").size().reset_index(name="#")
    hos_poscount = hos_poscount[hos_poscount["category"] != "others"].reset_index(drop=True)
    return hos_poscount

# %%
def  catagory_neg(neg_df): 
    neg_df ["category"] = neg_df["words"].apply(lambda x: groups(x))
    hos_negcount = neg_df.groupby("category").size().reset_index(name="#")
    hos_negcount =  hos_negcount[ hos_negcount["category"] != "others"].reset_index(drop=True)
    return hos_negcount

# %%
#poscount
bumrungrad_poscount = catagory_pos(bumrungrad_positive)
rajavithi_poscount = catagory_pos(rajavithi_positive)
lerdsin_poscount = catagory_pos(lerdsin_positive)

# %%
import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(go.Scatterpolar(
      r=bumrungrad_poscount["#"],
      theta= bumrungrad_poscount['category'],
      fill='toself',
      name='bumrungrad_positive'
))
fig.add_trace(go.Scatterpolar(
      r= rajavithi_poscount["#"],
      theta= rajavithi_poscount['category'],
      fill='toself',
      name='rajavithi_positive'
))
fig.add_trace(go.Scatterpolar(
      r= lerdsin_poscount["#"],
      theta=lerdsin_poscount['category'],
      fill='toself',
      name='lerdsin_positive'
))
fig.update_layout(
  polar=dict(
    radialaxis=dict(
      visible=True,
      range=[0, 6]
    )),
  showlegend=True
)
fig.show()
# Out:
# <div>
#
#
#             <div id="ca400f63-f784-4b73-9ee2-5832d1dbb908" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ca400f63-f784-4b73-9ee2-5832d1dbb908")) {
#                     Plotly.newPlot(
#                         'ca400f63-f784-4b73-9ee2-5832d1dbb908',
#                         [{"fill": "toself", "name": "bumrungrad_positive", "r": [1, 4, 1, 6, 3], "theta": ["finance", "infrastructure", "process", "service", "staff"], "type": "scatterpolar"}, {"fill": "toself", "name": "rajavithi_positive", "r": [6, 2, 6, 4], "theta": ["infrastructure", "process", "service", "staff"], "type": "scatterpolar"}, {"fill": "toself", "name": "lerdsin_positive", "r": [1, 5, 3, 6, 3], "theta": ["finance", "infrastructure", "process", "service", "staff"], "type": "scatterpolar"}],
#                         {"polar": {"radialaxis": {"range": [0, 6], "visible": true}}, "showlegend": true, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterte ...

# %%
#negcount
bumrungrad_negcount = catagory_neg(bumrungrad_negative)
rajavithi_negcount = catagory_neg(rajavithi_negative)
lerdsin_negcount = catagory_neg(lerdsin_negative)

# %%
import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(go.Scatterpolar(
      r=bumrungrad_negcount["#"],
      theta= bumrungrad_negcount['category'],
      fill='toself',
      name='bumrungrad_negative'
))
fig.add_trace(go.Scatterpolar(
      r= rajavithi_negcount["#"],
      theta= rajavithi_negcount['category'],
      fill='toself',
      name='rajavithi_negative'
))
fig.add_trace(go.Scatterpolar(
      r= lerdsin_negcount["#"],
      theta=lerdsin_negcount['category'],
      fill='toself',
      name='lerdsin_negative'
))
fig.update_layout(
  polar=dict(
    radialaxis=dict(
      visible=True,
      range=[0, 6]
    )),
  showlegend=True
)
fig.show()
# Out:
# <div>
#
#
#             <div id="04af34bb-f280-414d-8f15-2d0ebacd8140" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("04af34bb-f280-414d-8f15-2d0ebacd8140")) {
#                     Plotly.newPlot(
#                         '04af34bb-f280-414d-8f15-2d0ebacd8140',
#                         [{"fill": "toself", "name": "bumrungrad_negative", "r": [3, 2, 3, 2], "theta": ["infrastructure", "process", "service", "staff"], "type": "scatterpolar"}, {"fill": "toself", "name": "rajavithi_negative", "r": [4, 3, 4, 2], "theta": ["infrastructure", "process", "service", "staff"], "type": "scatterpolar"}, {"fill": "toself", "name": "lerdsin_negative", "r": [1, 4, 4, 6, 2], "theta": ["finance", "infrastructure", "process", "service", "staff"], "type": "scatterpolar"}],
#                         {"polar": {"radialaxis": {"range": [0, 6], "visible": true}}, "showlegend": true, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterte ...
